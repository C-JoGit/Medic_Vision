# %% [markdown]
# <a href="https://colab.research.google.com/github/C-JoGit/Medic_Vision/blob/main/TransferLearning_VGG16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
root_path = '/content/drive/MyDrive/pictures'
train_pred_test_folders = os.listdir(root_path)

seg_train_folders = '/content/drive/MyDrive/pictures/train/'
seg_test_folders = '/content/drive/MyDrive/pictures/val/'
seg_pred_folders = '/content/drive/MyDrive/pictures/pred/'
quantity_tr = {} 
quantity_te = {}
for folder in os.listdir(seg_train_folders):
    quantity_tr[folder] = len(os.listdir(seg_train_folders+folder))

for folder in os.listdir(seg_test_folders):
    quantity_te[folder] = len(os.listdir(seg_test_folders+folder))
    
quantity_train = pd.DataFrame(list(quantity_tr.items()), index=range(0,len(quantity_tr)), columns=['class','count'])
quantity_test = pd.DataFrame(list(quantity_te.items()), index=range(0,len(quantity_te)), columns=['class','count'])

figure, ax = plt.subplots(1,2,figsize=(20,5))
sns.barplot(x='class',y='count',data=quantity_train,ax=ax[0])
sns.barplot(x='class',y='count',data=quantity_test,ax=ax[1])

print("Number of images in the train set : ", sum(quantity_tr.values()))
print("Number of images in the test set ; ",sum(quantity_te.values()))
number_of_images_in_prediction_set = len(os.listdir(seg_pred_folders))
print("Number of images in prediction set : ",number_of_images_in_prediction_set)

plt.show()
# Out:
# Number of images in the train set :  130
# Number of images in the test set ;  17
# Number of images in prediction set :  16

# %%
def save_history(history, model_name):
    #convert the history.history dict to a pandas DataFrame:     
    hist_df = pd.DataFrame(history.history) 

    # save to json:  
    hist_json_file = model_name+'_history.json' 
    with open(hist_json_file, mode='w') as f:
        hist_df.to_json(f)

    # or save to csv: 
    hist_csv_file = model_name+'_history.csv'
    with open(hist_csv_file, mode='w') as f:
        hist_df.to_csv(f)
        
def plot_accuracy_from_history(history, isinception=False):
    color = sns.color_palette()
    if(isinception == False):
        acc = history.history['acc']
        val_acc = history.history['val_acc']
    else:
        acc = history.history['accuracy']
        val_acc = history.history['val_accuracy']
    

    epochs = range(len(acc))

    sns.lineplot(epochs, acc, label='Training Accuracy')
    sns.lineplot(epochs, val_acc,label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    plt.figure()
    plt.show()
    
def plot_loss_from_history(history):
    color = sns.color_palette()
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    epochs = range(len(loss))
    
    sns.lineplot(epochs, loss,label='Training Loss')
    sns.lineplot(epochs, val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.figure()
    plt.show()
    
def do_history_stuff(history, history_file_name, isinception=False):
    save_history(history, history_file_name)
    plot_accuracy_from_history(history, isinception)
    plot_loss_from_history(history)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator( rescale = 1.0/255.,shear_range=0.2,zoom_range=0.2)

# we are rescaling by 1.0/255 to normalize the rgb values if they are in range 0-255 the values are too high for good model performance. 
train_generator = train_datagen.flow_from_directory(seg_train_folders,
                                                    batch_size=32,
                                                    shuffle=True,
                                                    class_mode='categorical',
                                                    target_size=(150, 150))

validation_datagen = ImageDataGenerator(rescale = 1.0/255.) #we are only normalising to make the prediction, the other parameters were used for agumentation and train weights
validation_generator = validation_datagen.flow_from_directory(seg_test_folders, shuffle=True, batch_size=1, class_mode='categorical', target_size=(150, 150))
# Out:
# Found 130 images belonging to 16 classes.
# Found 16 images belonging to 16 classes.

# %%
inv_map_classes = {v: k for k, v in validation_generator.class_indices.items()}
print(validation_generator.class_indices)
print(inv_map_classes)
# Out:
# {'AltaPharmaEisen': 0, 'Bisoprolol': 1, 'Candecor': 2, 'CandesartanZantiva': 3, 'EunovaLangzeit': 4, 'GeloMytrol': 5, 'Ibuprofen400mg': 6, 'Imodium': 7, 'KlosterfrauBaldrianForte': 8, 'Lemocin': 9, 'Lorano': 10, 'Novaminsulfon': 11, 'Sedariston': 12, 'Taxofit': 13, 'Thomapyrin': 14, 'Vit4everVitaminB': 15}
# {0: 'AltaPharmaEisen', 1: 'Bisoprolol', 2: 'Candecor', 3: 'CandesartanZantiva', 4: 'EunovaLangzeit', 5: 'GeloMytrol', 6: 'Ibuprofen400mg', 7: 'Imodium', 8: 'KlosterfrauBaldrianForte', 9: 'Lemocin', 10: 'Lorano', 11: 'Novaminsulfon', 12: 'Sedariston', 13: 'Taxofit', 14: 'Thomapyrin', 15: 'Vit4everVitaminB'}

# %%
def show_few_images(number_of_examples=2, predict_using_model=None):
    figure1, ax1 = plt.subplots(number_of_examples,len(os.listdir(seg_train_folders)), figsize=(20,4*number_of_examples))
    ax1 = ax1.reshape(-1)
    axoff_fun = np.vectorize(lambda ax:ax.axis('off'))
    axoff_fun(ax1)
    axs = 0
    for i, folder in enumerate(os.listdir(seg_train_folders)):
        image_ids = os.listdir(os.path.join(seg_train_folders,folder))
        for j in [random.randrange(0, len(image_ids)) for i in range(0,number_of_examples)]:
            
            display = plt.imread(os.path.join(seg_train_folders,folder,image_ids[j]))
            plt.axis('off')
            ax1[axs].imshow(display)
            title = 'True:'+folder
            if(predict_using_model):
                predicted_classname = inv_map_classes[np.argmax(inception_best_model.predict(np.array([display])))]
                title = title+'\nPredict :'+predicted_classname
            ax1[axs].set_title(title)
            axs=axs+1

# %%
show_few_images(1)

# %%
import tensorflow as tf
tf.keras.backend.clear_session()

# epoch config
benchmark_epoch = 60
vgg_epoch = 60
resnet_epoch = 60
inception_epoch = 60

# %%
from tensorflow.keras import layers, Model
#random architecture
benchmark_model = tensorflow.keras.Sequential()
# Input here is 4D array (batchsize, height, width, channels) - we have already created the train_generator with batch size 32
# 32 Images of size each 150x150 with 3 color channels will be input into this layer
benchmark_model.add(layers.Conv2D(128, kernel_size=7, activation='relu', input_shape=(150,150,3)))
benchmark_model.add(layers.MaxPooling2D(pool_size=(4,4), strides=(2,2)))
benchmark_model.add(layers.Conv2D(64, kernel_size=5, activation='relu'))
benchmark_model.add(layers.MaxPooling2D(pool_size=(4,4), strides=(2,2)))
benchmark_model.add(layers.Flatten())
benchmark_model.add(layers.Dense(128,activation='relu'))
benchmark_model.add(layers.Dense(16,activation='softmax'))

benchmark_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])

benchmark_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 144, 144, 128)     18944
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 71, 71, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 67, 67, 64)        204864
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 65536)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               8388736
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                2064
# =================================================================
# Total params: 8,614,608
# Trainable params: 8,614,608
# Non-trainable params: 0
# _________________________________________________________________

# %%
#filepath = "bench_mark_-model-{epoch:02d}-{val_acc:.2f}.hdf5"
#reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.05, patience=5, min_lr=0.000002)
#checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
#early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
#history = benchmark_model.fit(train_generator,epochs=benchmark_epoch, verbose=1, validation_data = validation_generator,callbacks=[reduce_lr,early_stopping,checkpoint], steps_per_epoch=4, validation_steps=1)

#benchmark_model.save(filepath)
#do_history_stuff(history, 'benchmark_model')

# %%
filepath = "bench_mark_-model-{epoch:02d}-{val_acc:.2f}.hdf5"
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.05, patience=5, min_lr=0.000002)
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
history = benchmark_model.fit(train_generator, batch_size=10, epochs=benchmark_epoch, verbose=1, validation_data = validation_generator,callbacks=[reduce_lr,early_stopping,checkpoint], steps_per_epoch=13, validation_steps=2)

benchmark_model.save(filepath)
do_history_stuff(history, 'benchmark_model')
# Out:
# Epoch 1/20
# 13/13 [==============================] - 123s 8s/step - loss: 4.9590 - acc: 0.0885 - val_loss: 3.8446 - val_acc: 0.0000e+00
#
# Epoch 00001: val_acc improved from -inf to 0.00000, saving model to bench_mark_-model-01-0.00.hdf5
# Epoch 2/20
# 13/13 [==============================] - 98s 8s/step - loss: 2.5745 - acc: 0.1955 - val_loss: 2.9417 - val_acc: 0.0000e+00
#
# Epoch 00002: val_acc did not improve from 0.00000
# Epoch 3/20
# 13/13 [==============================] - 103s 8s/step - loss: 2.4847 - acc: 0.2043 - val_loss: 3.6572 - val_acc: 0.0000e+00
#
# Epoch 00003: val_acc did not improve from 0.00000
# Epoch 4/20
# 13/13 [==============================] - 101s 8s/step - loss: 2.0886 - acc: 0.2936 - val_loss: 3.7661 - val_acc: 0.0000e+00
#
# Epoch 00004: val_acc did not improve from 0.00000
# Epoch 5/20
# 13/13 [==============================] - 95s 7s/step - loss: 1.9836 - acc: 0.3541 - val_loss: 5.8606 - val_acc: 0.0000e+00
#
# Epoch 00005: val_acc did not improve from 0.00000
# Epoch 6/20
# 13/13 [==============================] - 109s 8s/step - loss: 1.3550 - acc: 0.5377 - val_loss: 6.0571 - val_acc: 0.0000e+00
#
# Epoch 00006: val_acc did not improve from 0.00000
# Epoch 7/20
# 13/13 [==============================] - 97s 7s/step - loss: 1.2142 - acc: 0.6158 - val_loss: 8.6408 - val_acc: 0.0000e+00
#
# Epoch 00007: val_acc did not improve from 0.00000
# Epoch 8/20
# 13/13 [==============================] - 104s 8s/step - loss: 0.8529 - acc: 0.6753 - val_loss: 10.4187 - val_acc: 0.0000e+00
#
# Epoch 00008: val_acc did not improve from 0.00000
# Epoch 9/20
# 13/13 [==============================] - 100s 8s/step - loss: 0.6558 - acc: 0.8018 - val_loss: 3.7779 - val_acc: 0.5000
#
# Epoch 00009: val_acc improved from 0.00000 to 0.50000, saving model to bench_mark_-model-09-0.50.hdf5
# Epoch 10/20
# 13/13 [==============================] - 95s 7s/step - loss: 0.6283 - acc: 0.8282 - val_loss: 0.9517 - val_acc: 0.5000
#
# Epoch 00010: val_acc did not improve from 0.50000
# Epoch 11/20
# 13/13 [==============================] - 108s 8s/step - loss: 0.5777 - acc: 0.8368 - val_loss: 10.4669 - val_acc: 0.0000e+00
#
# Epoch 00011: val_acc did not improve from 0.50000
# Epoch 12/20
# 13/13 [==============================] - 97s 8s/step - loss: 0.5801 - acc: 0.8537 - val_loss: 6.5939 - val_acc: 0.5000
#
# Epoch 00012: val_acc did not improve from 0.50000
# Epoch 13/20
# 13/13 [==============================] - 104s 8s/step - loss: 0.5022 - acc: 0.8307 - val_loss: 4.3455 - val_acc: 0.5000
#
# Epoch 00013: val_acc did not improve from 0.50000
# Epoch 14/20
# 13/13 [==============================] - 100s 8s/step - loss: 0.4741 - acc: 0.9013 - val_loss: 8.3585 - val_acc: 0.5000
#
# Epoch 00014: val_acc did not improve from 0.50000
# Epoch 15/20
# 13/13 [==============================] - 96s 7s/step - loss: 0.4829 - acc: 0.8757 - val_loss: 13.4027 - val_acc: 0.0000e+00
#
# Epoch 00015: val_acc did not improve from 0.50000
# Epoch 16/20
# 13/13 [==============================] - 108s 8s/step - loss: 0.4246 - acc: 0.8664 - val_loss: 8.4738 - val_acc: 0.0000e+00
#
# Epoch 00016: val_acc did not improve from 0.50000
# Epoch 17/20
# 13/13 [==============================] - 98s 8s/step - loss: 0.5176 - acc: 0.8815 - val_loss: 11.1608 - val_acc: 0.0000e+00
#
# Epoch 00017: val_acc did not improve from 0.50000
# Epoch 18/20
# 13/13 [==============================] - 103s 8s/step - loss: 0.4618 - acc: 0.8926 - val_loss: 7.8227 - val_acc: 0.0000e+00
#
# Epoch 00018: val_acc did not improve from 0.50000
# Epoch 19/20
# 13/13 [==============================] - 100s 8s/step - loss: 0.4204 - acc: 0.9287 - val_loss: 2.9759 - val_acc: 0.0000e+00
#
# Epoch 00019: val_acc did not improve from 0.50000
# Epoch 20/20
# 13/13 [==============================] - 95s 7s/step - loss: 0.4546 - acc: 0.8943 - val_loss: 1.4615 - val_acc: 0.0000e+00
#
# Epoch 00020: val_acc did not improve from 0.50000
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import GlobalMaxPooling2D, GlobalAveragePooling2D, Dropout, Dense, Input, Conv2D, MaxPooling2D, Flatten,MaxPooling3D
vgg16_model = VGG16(pooling='avg', weights='imagenet', include_top=False, input_shape=(150,150,3))
for layers in vgg16_model.layers:
            layers.trainable=False
last_output = vgg16_model.layers[-1].output
vgg_x = tf.keras.layers.Flatten()(last_output)
vgg_x = Dense(128, activation = 'relu')(vgg_x)
vgg_x = Dense(16, activation = 'softmax')(vgg_x)
vgg16_final_model = Model(vgg16_model.input, vgg_x)
vgg16_final_model.compile(loss = 'categorical_crossentropy', optimizer= 'adam', metrics=['acc'])

# VGG16
number_of_epochs = vgg_epoch
vgg16_filepath = 'vgg_16_'+'-saved-model-{epoch:02d}-acc-{val_acc:.2f}.hdf5'
vgg_checkpoint = tf.keras.callbacks.ModelCheckpoint(vgg16_filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
vgg_early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)
vgg16_history = vgg16_final_model.fit(train_generator, epochs = 60 ,validation_data = validation_generator,callbacks=[vgg_checkpoint,vgg_early_stopping],verbose=1)

do_history_stuff(vgg16_history, 'vgg16_model')
# Out:
# Epoch 1/60
# 5/5 [==============================] - 47s 9s/step - loss: 2.8109 - acc: 0.0923 - val_loss: 2.8841 - val_acc: 0.0625
#
# Epoch 00001: val_acc improved from -inf to 0.06250, saving model to vgg_16_-saved-model-01-acc-0.06.hdf5
# Epoch 2/60
# 5/5 [==============================] - 38s 9s/step - loss: 2.6081 - acc: 0.1692 - val_loss: 2.9565 - val_acc: 0.0625
#
# Epoch 00002: val_acc did not improve from 0.06250
# Epoch 3/60
# 5/5 [==============================] - 39s 7s/step - loss: 2.5370 - acc: 0.1769 - val_loss: 2.9553 - val_acc: 0.0625
#
# Epoch 00003: val_acc did not improve from 0.06250
# Epoch 4/60
# 5/5 [==============================] - 39s 9s/step - loss: 2.5223 - acc: 0.1692 - val_loss: 2.9279 - val_acc: 0.0625
#
# Epoch 00004: val_acc did not improve from 0.06250
# Epoch 5/60
# 5/5 [==============================] - 38s 7s/step - loss: 2.4267 - acc: 0.1846 - val_loss: 2.7345 - val_acc: 0.0625
#
# Epoch 00005: val_acc did not improve from 0.06250
# Epoch 6/60
# 5/5 [==============================] - 39s 8s/step - loss: 2.3342 - acc: 0.3154 - val_loss: 2.6256 - val_acc: 0.1250
#
# Epoch 00006: val_acc improved from 0.06250 to 0.12500, saving model to vgg_16_-saved-model-06-acc-0.12.hdf5
# Epoch 7/60
# 5/5 [==============================] - 39s 7s/step - loss: 2.2631 - acc: 0.3769 - val_loss: 2.5883 - val_acc: 0.0625
#
# Epoch 00007: val_acc did not improve from 0.12500
# Epoch 8/60
# 5/5 [==============================] - 39s 7s/step - loss: 2.2256 - acc: 0.4231 - val_loss: 2.5854 - val_acc: 0.0625
#
# Epoch 00008: val_acc did not improve from 0.12500
# Epoch 9/60
# 5/5 [==============================] - 38s 7s/step - loss: 2.1595 - acc: 0.4000 - val_loss: 2.5948 - val_acc: 0.1250
#
# Epoch 00009: val_acc did not improve from 0.12500
# Epoch 10/60
# 5/5 [==============================] - 38s 9s/step - loss: 2.1084 - acc: 0.4077 - val_loss: 2.5677 - val_acc: 0.0625
#
# Epoch 00010: val_acc did not improve from 0.12500
# Epoch 11/60
# 5/5 [==============================] - 39s 7s/step - loss: 2.0552 - acc: 0.4154 - val_loss: 2.5317 - val_acc: 0.0625
#
# Epoch 00011: val_acc did not improve from 0.12500
# Epoch 12/60
# 5/5 [==============================] - 39s 7s/step - loss: 1.9959 - acc: 0.4692 - val_loss: 2.5050 - val_acc: 0.0625
#
# Epoch 00012: val_acc did not improve from 0.12500
# Epoch 13/60
# 5/5 [==============================] - 38s 7s/step - loss: 1.9559 - acc: 0.4769 - val_loss: 2.5021 - val_acc: 0.0625
#
# Epoch 00013: val_acc did not improve from 0.12500
# Epoch 14/60
# 5/5 [==============================] - 39s 7s/step - loss: 1.9114 - acc: 0.4077 - val_loss: 2.4960 - val_acc: 0.0625
#
# Epoch 00014: val_acc did not improve from 0.12500
# Epoch 15/60
# 5/5 [==============================] - 38s 7s/step - loss: 1.8456 - acc: 0.4077 - val_loss: 2.4903 - val_acc: 0.0625
#
# Epoch 00015: val_acc did not improve from 0.12500
# Epoch 16/60
# 5/5 [==============================] - 39s 7s/step - loss: 1.7958 - acc: 0.4385 - val_loss: 2.4924 - val_acc: 0.1250
#
# Epoch 00016: val_acc did not improve from 0.12500
# Epoch 17/60
# 5/5 [==============================] - 39s 7s/step - loss: 1.7573 - acc: 0.4615 - val_loss: 2.4249 - val_acc: 0.1250
#
# Epoch 00017: val_acc did not improve from 0.12500
# Epoch 18/60
# 5/5 [==============================] - 39s 7s/step - loss: 1.7152 - acc: 0.5154 - val_loss: 2.3731 - val_acc: 0.0625
#
# Epoch 00018: val_acc did not improve from 0.12500
# Epoch 19/60
# 5/5 [==============================] - 38s 7s/step - loss: 1.6982 - acc: 0.5077 - val_loss: 2.3661 - val_acc: 0.1250
#
# Epoch 00019: val_acc did not improve from 0.12500
# Epoch 20/60
# 5/5 [==============================] - 38s 9s/step - loss: 1.6487 - acc: 0.5385 - val_loss: 2.3785 - val_acc: 0.1250
#
# Epoch 00020: val_acc did not improve from 0.12500
# Epoch 21/60
# 5/5 [==============================] - 39s 7s/step - loss: 1.5966 - acc: 0.6154 - val_loss: 2.4280 - val_acc: 0.0625
#
# Epoch 00021: val_acc did not improve from 0.12500
# Epoch 22/60
# 5/5 [==============================] - 39s 9s/step - loss: 1.5829 - acc: 0.6154 - val_loss: 2.4230 - val_acc: 0.1250
#
# Epoch 00022: val_acc did not improve from 0.12500
# Epoch 23/60
# 5/5 [==============================] - 39s 7s/step - loss: 1.5535 - acc: 0.5923 - val_loss: 2.3797 - val_acc: 0.1250
#
# Epoch 00023: val_acc did not improve from 0.12500
# Epoch 24/60
# 5/5 [==============================] - 39s 7s/step - loss: 1.5166 - acc: 0.6385 - val_loss: 2.3666 - val_acc: 0.1250
#
# Epoch 00024: val_acc did not improve from 0.12500
# Epoch 25/60
# 5/5 [==============================] - 38s 9s/step - loss: 1.4944 - acc: 0.6231 - val_loss: 2.4355 - val_acc: 0.0625
#
# Epoch 00025: val_acc did not improve from 0.12500
# Epoch 26/60
# 5/5 [==============================] - 39s 7s/step - loss: 1.4545 - acc: 0.6231 - val_loss: 2.4211 - val_acc: 0.0625
#
# Epoch 00026: val_acc did not improve from 0.12500
# Epoch 27/60
# 5/5 [==============================] - 39s 7s/step - loss: 1.4273 - acc: 0.6077 - val_loss: 2.3853 - val_acc: 0.0625
#
# Epoch 00027: val_acc did not improve from 0.12500
# Epoch 28/60
# 5/5 [==============================] - 38s 7s/step - loss: 1.3924 - acc: 0.6077 - val_loss: 2.3653 - val_acc: 0.1250
#
# Epoch 00028: val_acc did not improve from 0.12500
# Epoch 29/60
# 5/5 [==============================] - 39s 7s/step - loss: 1.3519 - acc: 0.6462 - val_loss: 2.3849 - val_acc: 0.1250
#
# Epoch 00029: val_acc did not improve from 0.12500
# Epoch 30/60
# 5/5 [==============================] - 39s 7s/step - loss: 1.3388 - acc: 0.6538 - val_loss: 2.4032 - val_acc: 0.1250
#
# Epoch 00030: val_acc did not improve from 0.12500
# Epoch 31/60
# 5/5 [==============================] - 39s 8s/step - loss: 1.3504 - acc: 0.6308 - val_loss: 2.4226 - val_acc: 0.1250
#
# Epoch 00031: val_acc did not improve from 0.12500
# Epoch 32/60
# 5/5 [==============================] - 39s 7s/step - loss: 1.2899 - acc: 0.7077 - val_loss: 2.4089 - val_acc: 0.1250
#
# Epoch 00032: val_acc did not improve from 0.12500
# Epoch 33/60
# 5/5 [==============================] - 38s 9s/step - loss: 1.2849 - acc: 0.7077 - val_loss: 2.3480 - val_acc: 0.2500
#
# Epoch 00033: val_acc improved from 0.12500 to 0.25000, saving model to vgg_16_-saved-model-33-acc-0.25.hdf5
# Epoch 34/60
# 5/5 [==============================] - 39s 7s/step - loss: 1.2831 - acc: 0.6692 - val_loss: 2.2904 - val_acc: 0.2500
#
# Epoch 00034: val_acc did not improve from 0.25000
# Epoch 35/60
# 5/5 [==============================] - 38s 7s/step - loss: 1.2464 - acc: 0.6923 - val_loss: 2.2655 - val_acc: 0.2500
#
# Epoch 00035: val_acc did not improve from 0.25000
# Epoch 36/60
# 5/5 [==============================] - 38s 7s/step - loss: 1.2013 - acc: 0.7385 - val_loss: 2.2559 - val_acc: 0.2500
#
# Epoch 00036: val_acc did not improve from 0.25000
# Epoch 37/60
# 5/5 [==============================] - 39s 7s/step - loss: 1.1762 - acc: 0.7385 - val_loss: 2.2342 - val_acc: 0.2500
#
# Epoch 00037: val_acc did not improve from 0.25000
# Epoch 38/60
# 5/5 [==============================] - 39s 10s/step - loss: 1.1697 - acc: 0.7692 - val_loss: 2.2180 - val_acc: 0.2500
#
# Epoch 00038: val_acc did not improve from 0.25000
# Epoch 39/60
# 5/5 [==============================] - 39s 10s/step - loss: 1.1571 - acc: 0.7615 - val_loss: 2.2648 - val_acc: 0.2500
#
# Epoch 00039: val_acc did not improve from 0.25000
# Epoch 40/60
# 5/5 [==============================] - 40s 8s/step - loss: 1.1345 - acc: 0.7692 - val_loss: 2.3145 - val_acc: 0.2500
#
# Epoch 00040: val_acc did not improve from 0.25000
# Epoch 41/60
# 5/5 [==============================] - 39s 10s/step - loss: 1.1155 - acc: 0.7769 - val_loss: 2.3333 - val_acc: 0.3125
#
# Epoch 00041: val_acc improved from 0.25000 to 0.31250, saving model to vgg_16_-saved-model-41-acc-0.31.hdf5
# Epoch 42/60
# 5/5 [==============================] - 39s 8s/step - loss: 1.0890 - acc: 0.7385 - val_loss: 2.3493 - val_acc: 0.1875
#
# Epoch 00042: val_acc did not improve from 0.31250
# Epoch 43/60
# 5/5 [==============================] - 38s 9s/step - loss: 1.1015 - acc: 0.6923 - val_loss: 2.4313 - val_acc: 0.1250
#
# Epoch 00043: val_acc did not improve from 0.31250
# Epoch 44/60
# 5/5 [==============================] - 39s 7s/step - loss: 1.0934 - acc: 0.6385 - val_loss: 2.4539 - val_acc: 0.1250
#
# Epoch 00044: val_acc did not improve from 0.31250
# Epoch 45/60
# 5/5 [==============================] - 39s 10s/step - loss: 1.0637 - acc: 0.7154 - val_loss: 2.5080 - val_acc: 0.0625
#
# Epoch 00045: val_acc did not improve from 0.31250
# Epoch 46/60
# 5/5 [==============================] - 39s 10s/step - loss: 0.9868 - acc: 0.8077 - val_loss: 2.4670 - val_acc: 0.3125
#
# Epoch 00046: val_acc did not improve from 0.31250
# Epoch 47/60
# 5/5 [==============================] - 38s 9s/step - loss: 1.0206 - acc: 0.7923 - val_loss: 2.3936 - val_acc: 0.2500
#
# Epoch 00047: val_acc did not improve from 0.31250
# Epoch 48/60
# 5/5 [==============================] - 38s 9s/step - loss: 1.0014 - acc: 0.8000 - val_loss: 2.3169 - val_acc: 0.3125
#
# Epoch 00048: val_acc did not improve from 0.31250
# Epoch 49/60
# 5/5 [==============================] - 39s 7s/step - loss: 0.9764 - acc: 0.7769 - val_loss: 2.2741 - val_acc: 0.3125
#
# Epoch 00049: val_acc did not improve from 0.31250
# Epoch 50/60
# 5/5 [==============================] - 38s 7s/step - loss: 0.9742 - acc: 0.7538 - val_loss: 2.2773 - val_acc: 0.3125
#
# Epoch 00050: val_acc did not improve from 0.31250
# Epoch 51/60
# 5/5 [==============================] - 38s 7s/step - loss: 0.9874 - acc: 0.7385 - val_loss: 2.3138 - val_acc: 0.3125
#
# Epoch 00051: val_acc did not improve from 0.31250
# Epoch 52/60
# 5/5 [==============================] - 39s 8s/step - loss: 0.9417 - acc: 0.7846 - val_loss: 2.3155 - val_acc: 0.3125
#
# Epoch 00052: val_acc did not improve from 0.31250
# Epoch 53/60
# 5/5 [==============================] - 38s 7s/step - loss: 0.9335 - acc: 0.8154 - val_loss: 2.3253 - val_acc: 0.3125
#
# Epoch 00053: val_acc did not improve from 0.31250
# Epoch 54/60
# 5/5 [==============================] - 38s 9s/step - loss: 0.9118 - acc: 0.8385 - val_loss: 2.3229 - val_acc: 0.2500
#
# Epoch 00054: val_acc did not improve from 0.31250
# Epoch 55/60
# 5/5 [==============================] - 39s 7s/step - loss: 0.9156 - acc: 0.8385 - val_loss: 2.3448 - val_acc: 0.3750
#
# Epoch 00055: val_acc improved from 0.31250 to 0.37500, saving model to vgg_16_-saved-model-55-acc-0.38.hdf5
# Epoch 56/60
# 5/5 [==============================] - 40s 7s/step - loss: 0.9002 - acc: 0.8385 - val_loss: 2.3756 - val_acc: 0.4375
#
# Epoch 00056: val_acc improved from 0.37500 to 0.43750, saving model to vgg_16_-saved-model-56-acc-0.44.hdf5
# Epoch 57/60
# 5/5 [==============================] - 40s 7s/step - loss: 0.8724 - acc: 0.8231 - val_loss: 2.4090 - val_acc: 0.3125
#
# Epoch 00057: val_acc did not improve from 0.43750
# Epoch 58/60
# 5/5 [==============================] - 39s 7s/step - loss: 0.8898 - acc: 0.7923 - val_loss: 2.4215 - val_acc: 0.3125
#
# Epoch 00058: val_acc did not improve from 0.43750
# Epoch 59/60
# 5/5 [==============================] - 40s 8s/step - loss: 0.8854 - acc: 0.8000 - val_loss: 2.3672 - val_acc: 0.2500
#
# Epoch 00059: val_acc did not improve from 0.43750
# Epoch 60/60
# 5/5 [==============================] - 39s 10s/step - loss: 0.8668 - acc: 0.7769 - val_loss: 2.4595 - val_acc: 0.2500
#
# Epoch 00060: val_acc did not improve from 0.43750
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
